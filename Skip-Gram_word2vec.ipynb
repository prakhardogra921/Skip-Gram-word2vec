# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:11, 2.79MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
from random import random

t = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
frequencies = {}
for word in word_counts:
    frequencies[word] = word_counts[word]/total_count
prob = {}
for word in word_counts:
    prob[word] = 1 - np.sqrt(t/frequencies[word])
train_words = []# The final subsampled word list
for word in int_words:
    if random() < (1 - prob[word]):
    # can also do prob[word] < random()
        train_words.append(word)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1, window_size + 1)
    if idx - r < 0:
        start_idx = 0
    else:
        start_idx = idx - r
    end_idx = idx + r
    
    target = set(words[start_idx: idx] + words[idx + 1: end_idx + 1])
    
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = "inputs")
    labels = tf.placeholder(tf.int32, [None, None], name = "labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
from random import sample

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.2006 0.5262 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.1308 0.5283 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.9324 0.5600 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.7150 0.5787 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.4061 0.5131 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.0136 0.5115 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.7212 0.5137 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5274 0.5270 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5104 0.5960 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4226 0.5860 sec/batch
# Nearest to was: almost, storage, random, understand, frederick, retrospective, market, west,
# Nearest to its: secular, lenders, affricates, eternity, bay, whatever, personnel, retirement,
# Nearest to over: seamonkey, tyrannical, shows, servitude, whatever, went, general, status,
# Nearest to when: india, writers, narrower, anyone, kerguelen, steel, useful, kensington,
# Nearest to have: new, bombers, prone, name, shortly, goal, preference, sixth,
# Nearest to who: before, humanism, joiner, greatness, erechtheus, simply, story, prosperity,
# Nearest to were: why, living, reproached, writing, introduction, experienced, devastated, lay,
# Nearest to known: differences, idea, wilderness, businesses, robert, beyond, principal, berbice,
# Nearest to event: collected, withdrawal, whether, orthodoxy, tracker, dekalb, shatter, yarrow,
# Nearest to pope: district, conquistadores, accordingly, obeying, dive, catching, ponderosa, arafura,
# Nearest to construction: scrutiny, describing, prolific, lieutenant, santiago, pinguinus, harvests, occupations,
# Nearest to scale: characteristics, succeeding, bharata, agrees, depots, man, marries, qantas,
# Nearest to issue: station, ad, redman, quoted, charis, rapping, reach, carried,
# Nearest to dr: unwarranted, cremated, cavities, masashi, discussion, both, akc, develop,
# Nearest to operating: references, ex, odds, coppola, biathlon, intertoto, freedom, hydrolysis,
# Nearest to prince: therefore, publications, breeding, losing, docetism, hollow, rv, sole,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.2887 0.5914 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.2539 0.5970 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.1619 0.5566 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1387 0.5142 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1129 0.4776 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0838 0.3537 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9909 0.3532 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0615 0.3539 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0217 0.3532 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9956 0.3558 sec/batch
# Nearest to was: leopold, retrospective, broadcast, attack, scorn, agence, consisting, storage,
# Nearest to its: affricates, secular, personnel, lenders, retirement, covering, eternity, analogous,
# Nearest to over: seamonkey, tyrannical, shows, emir, whatever, servitude, realization, pozsony,
# Nearest to when: india, narrower, writers, steel, kensington, populous, this, baltimore,
# Nearest to have: bombers, prone, preference, abundance, myth, goal, taxonomic, humphry,
# Nearest to who: before, spectra, prosperity, joiner, possessed, humanism, erechtheus, communication,
# Nearest to were: lay, writing, reproached, defence, why, ritual, experienced, devastated,
# Nearest to known: differences, wilderness, idea, businesses, farming, beyond, principal, berbice,
# Nearest to event: guns, orthodoxy, withdrawal, collected, tracker, dekalb, whether, yarrow,
# Nearest to pope: district, conquistadores, viii, catching, balkans, crises, ponderosa, oireachtas,
# Nearest to construction: scrutiny, describing, santiago, prolific, harvests, lieutenant, occupations, rainfall,
# Nearest to scale: characteristics, succeeding, depots, agrees, man, qantas, marries, jo,
# Nearest to issue: station, redman, rapping, ad, quoted, cincinnati, charis, reporting,
# Nearest to dr: unwarranted, cremated, runway, cure, akc, cavities, masashi, jumping,
# Nearest to operating: odds, ex, professional, freedom, wildlife, intertoto, divinely, references,
# Nearest to prince: publications, saturday, rugby, geneticists, hollow, losing, hodgkin, docetism,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9517 0.3602 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8900 0.3569 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9149 0.3541 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9436 0.3581 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9177 0.3551 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8822 0.3540 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8352 0.3535 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8217 0.3528 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7307 0.3543 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8536 0.3540 sec/batch
# Nearest to was: leopold, retrospective, dependencies, scorn, lightened, propensity, agence, rez,
# Nearest to its: affricates, secular, personnel, covering, sweeps, retirement, supply, lenders,
# Nearest to over: seamonkey, tyrannical, realization, emir, shows, pozsony, hebron, hooke,
# Nearest to when: india, kensington, this, narrower, writers, baltimore, steel, populous,
# Nearest to have: bombers, prone, humphry, myth, preference, abundance, focuses, goal,
# Nearest to who: before, spectra, joiner, erechtheus, refered, possessed, prosperity, humanism,
# Nearest to were: lay, defence, reproached, ritual, writing, leaders, why, britons,
# Nearest to known: differences, wilderness, idea, farming, beyond, businesses, gehrig, principal,
# Nearest to event: capitalism, guns, orthodoxy, withdrawal, tracker, yarrow, bloodshed, te,
# Nearest to pope: district, conquistadores, crises, tabriz, balkans, viii, lefty, ponderosa,
# Nearest to construction: scrutiny, describing, santiago, vests, milestone, harvests, prolific, floss,
# Nearest to scale: characteristics, succeeding, depots, profumo, man, concretes, jo, anticipation,
# Nearest to issue: station, redman, rapping, opting, rajput, ad, reach, kh,
# Nearest to dr: cremated, unwarranted, akc, masashi, interchangeable, opting, cure, jumping,
# Nearest to operating: ex, odds, professional, freedom, ostensible, intertoto, coppola, biathlon,
# Nearest to prince: saturday, publications, augmented, docetism, geneticists, electing, visibility, rugby,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7885 0.3587 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7893 0.3534 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.8335 0.3511 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7972 0.3553 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7637 0.3563 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.8201 0.4757 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.8124 0.4837 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7603 0.4841 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7799 0.4841 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7272 0.4854 sec/batch
# Nearest to was: scorn, dependencies, rez, leopold, retrospective, agence, suspended, chooses,
# Nearest to its: affricates, secular, sweeps, personnel, covering, it, supply, lenders,
# Nearest to over: seamonkey, tyrannical, readiness, emir, realization, shows, pozsony, hooke,
# Nearest to when: narrower, next, this, kensington, india, urgent, anyone, steel,
# Nearest to have: prone, bombers, calumet, ever, perl, humphry, dried, myth,
# Nearest to who: before, spectra, erechtheus, refered, joiner, possessed, story, humanism,
# Nearest to were: lay, defence, reproached, leaders, meteor, experienced, britons, authentication,
# Nearest to known: wilderness, differences, farming, idea, beyond, gehrig, businesses, berbice,
# Nearest to event: capitalism, guns, tracker, gskola, withdrawal, orthodoxy, fringes, minicomputers,
# Nearest to pope: district, conquistadores, viii, oireachtas, tabriz, ponderosa, clipper, lefty,
# Nearest to construction: scrutiny, describing, santiago, vests, milestone, harvests, promotions, floss,
# Nearest to scale: depots, characteristics, succeeding, contamination, domesday, mechanical, concretes, profumo,
# Nearest to issue: redman, station, opting, rapping, reorient, rajput, ad, reach,
# Nearest to dr: cremated, unwarranted, masashi, redesign, akc, opting, interchangeable, cavities,
# Nearest to operating: ex, plumbing, odds, professional, freedom, intertoto, matching, dyer,
# Nearest to prince: saturday, docetism, rugby, geneticists, reintroduction, publications, diaghilev, losing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7384 0.4880 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7824 0.4872 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.7163 0.4860 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.7323 0.4879 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6883 0.4879 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.7420 0.4879 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.7268 0.4889 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.7437 0.4854 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.7132 0.4904 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.7052 0.4908 sec/batch
# Nearest to was: scorn, respond, agence, suspended, chooses, alba, posthumously, rez,
# Nearest to its: affricates, personnel, it, sweeps, secular, supply, covering, consonants,
# Nearest to over: seamonkey, tyrannical, emir, readiness, encased, realization, shows, hebron,
# Nearest to when: next, kensington, urgent, fabric, this, steel, fire, india,
# Nearest to have: prone, calumet, ever, bombers, dried, hacking, humphry, taxonomic,
# Nearest to who: before, erechtheus, spectra, story, joiner, nonsensical, receptive, possessed,
# Nearest to were: lay, reproached, defence, leaders, rhotic, authentication, experienced, britons,
# Nearest to known: wilderness, differences, farming, beyond, idea, gehrig, berbice, greatest,
# Nearest to event: guns, tracker, capitalism, gskola, minicomputers, fringes, lymph, whether,
# Nearest to pope: district, viii, conquistadores, oireachtas, tabriz, lefty, clipper, ponderosa,
# Nearest to construction: scrutiny, describing, santiago, vests, harvests, milestone, promotions, floss,
# Nearest to scale: depots, characteristics, succeeding, domesday, contamination, increase, profumo, dorset,
# Nearest to issue: redman, rapping, opting, reorient, station, caldera, rajput, kh,
# Nearest to dr: masashi, cremated, redesign, akc, unwarranted, opting, interchangeable, mathematica,
# Nearest to operating: dyer, plumbing, ex, odds, coppola, creationist, matching, intertoto,
# Nearest to prince: docetism, saturday, reintroduction, rugby, der, tigris, publications, earths,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6645 0.4907 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6727 0.4892 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.6395 0.4885 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6834 0.4912 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.6738 0.4937 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.6758 0.4961 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.6653 0.5000 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.6377 0.4910 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.6728 0.4955 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.6227 0.4971 sec/batch
# Nearest to was: scorn, sitter, respond, posthumously, rez, chooses, alba, suspended,
# Nearest to its: it, affricates, personnel, covering, secular, sweeps, incurred, consonants,
# Nearest to over: seamonkey, tyrannical, encased, emir, triangles, readiness, realization, vedas,
# Nearest to when: next, kensington, urgent, this, narrower, fire, move, steel,
# Nearest to have: calumet, ever, prone, fujiwara, taxonomic, dried, very, disabilities,
# Nearest to who: before, erechtheus, hagia, possessed, joiner, receptive, refered, splitting,
# Nearest to were: lay, reproached, leaders, authentication, britons, rhotic, intertwining, defence,
# Nearest to known: wilderness, differences, beyond, farming, greatest, gehrig, idea, berbice,
# Nearest to event: guns, capitalism, gskola, tracker, minicomputers, whether, lymph, fringes,
# Nearest to pope: viii, conquistadores, oireachtas, district, tabriz, lefty, abdicated, agaves,
# Nearest to construction: scrutiny, describing, vests, santiago, promotions, floss, milestone, harvests,
# Nearest to scale: depots, characteristics, succeeding, domesday, naively, contamination, increase, mechanical,
# Nearest to issue: redman, rapping, reorient, rajput, opting, station, caldera, kh,
# Nearest to dr: masashi, cremated, redesign, opting, willamette, akc, mathematica, unwarranted,
# Nearest to operating: dyer, plumbing, matching, ex, bocce, creationist, professional, intertoto,
# Nearest to prince: reintroduction, saturday, docetism, den, rugby, tigris, diaghilev, wodehouse,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.6282 0.4758 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.6421 0.3621 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.6421 0.3665 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.6519 0.3659 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.6313 0.3629 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.6074 0.3631 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5886 0.4003 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.6192 0.4894 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.6544 0.4857 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.6474 0.4899 sec/batch
# Nearest to was: sitter, respond, chooses, posthumously, another, scorn, later, agence,
# Nearest to its: it, affricates, personnel, sweeps, inquire, covering, consonants, supply,
# Nearest to over: seamonkey, tyrannical, encased, emir, cincinnatus, pozsony, hooke, vedas,
# Nearest to when: next, kensington, urgent, move, fire, after, this, anyone,
# Nearest to have: fujiwara, ever, calumet, prone, dried, very, indicate, elevated,
# Nearest to who: before, erechtheus, possessed, hagia, refered, joiner, receptive, spectra,
# Nearest to were: lay, leaders, reproached, intertwining, rhotic, britons, authentication, defence,
# Nearest to known: wilderness, differences, farming, greatest, gehrig, idea, diskette, berbice,
# Nearest to event: guns, gskola, capitalism, tracker, minicomputers, whether, asked, lymph,
# Nearest to pope: viii, conquistadores, oireachtas, tabriz, district, agaves, abdicated, lefty,
# Nearest to construction: scrutiny, describing, vests, harvests, pinguinus, santiago, promotions, floss,
# Nearest to scale: depots, naively, succeeding, characteristics, domesday, undesirables, increase, deviating,
# Nearest to issue: redman, reorient, rajput, rapping, opting, caldera, brinkley, kh,
# Nearest to dr: masashi, cremated, redesign, opting, willamette, mathematica, akc, thoracic,
# Nearest to operating: microsoft, dyer, plumbing, matching, bocce, creationist, professional, ex,
# Nearest to prince: reintroduction, rioted, docetism, saturday, rugby, wodehouse, den, diaghilev,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.6576 0.4865 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.6310 0.4829 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5432 0.4832 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.6252 0.4864 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.6450 0.4889 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.6189 0.4952 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.6178 0.4901 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.6186 0.4908 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.5926 0.4986 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.6309 0.4829 sec/batch
# Nearest to was: sitter, respond, another, leopold, alba, exploration, later, vile,
# Nearest to its: it, affricates, inquire, secular, personnel, covering, electromotive, sweeps,
# Nearest to over: seamonkey, tyrannical, encased, prussian, emir, cincinnatus, oviedo, gym,
# Nearest to when: next, kensington, move, fire, this, clotting, after, remember,
# Nearest to have: ever, fujiwara, calumet, dried, prone, indicate, preference, elevated,
# Nearest to who: before, erechtheus, possessed, receptive, joiner, seek, refered, hagia,
# Nearest to were: lay, britons, rhotic, reproached, soldiers, resistance, leaders, intertwining,
# Nearest to known: wilderness, greatest, diskette, differences, farming, berbice, beyond, gehrig,
# Nearest to event: gskola, guns, capitalism, tracker, minicomputers, whether, insecticide, sopranos,
# Nearest to pope: viii, conquistadores, abdicated, lengthy, agaves, tabriz, oireachtas, grandson,
# Nearest to construction: scrutiny, describing, promotions, vests, santiago, pinguinus, floss, harvests,
# Nearest to scale: depots, naively, succeeding, increase, characteristics, undesirables, contamination, domesday,
# Nearest to issue: redman, reorient, rajput, telescopes, tyndareus, brinkley, caldera, rapping,
# Nearest to dr: masashi, cremated, opting, mathematica, theon, redesign, willamette, blackwood,
# Nearest to operating: microsoft, dyer, plumbing, matching, bocce, professional, miramax, ex,
# Nearest to prince: rioted, reintroduction, docetism, wodehouse, saturday, bombs, electing, rugby,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.5834 0.4842 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.4971 0.4758 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.5645 0.4828 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5645 0.4846 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.5696 0.4822 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.5310 0.4804 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.6155 0.4367 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4223 0.4207 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.4261 0.4293 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.4508 0.4314 sec/batch
# Nearest to was: later, another, alba, sitter, posthumously, napoleon, respond, leopold,
# Nearest to its: it, personnel, affricates, secular, inquire, psychohistory, sweeps, incurred,
# Nearest to over: seamonkey, tyrannical, prussian, cincinnatus, oviedo, pozsony, encased, hebron,
# Nearest to when: next, kensington, after, move, this, afterwards, fire, anyone,
# Nearest to have: fujiwara, ever, calumet, has, disabilities, prone, hoses, dried,
# Nearest to who: erechtheus, before, possessed, seek, grandchildren, hagia, receptive, joiner,
# Nearest to were: lay, rhotic, britons, reproached, their, are, amply, soldiers,
# Nearest to known: wilderness, greatest, diskette, berbice, baar, farming, bart, grand,
# Nearest to event: gskola, guns, capitalism, tracker, minicomputers, castaneda, athenaeus, sopranos,
# Nearest to pope: viii, conquistadores, abdicated, agaves, grandson, tabriz, oireachtas, lengthy,
# Nearest to construction: scrutiny, santiago, describing, vests, promotions, pinguinus, floss, motorway,
# Nearest to scale: depots, succeeding, increase, naively, domesday, undesirables, vantaa, deviating,
# Nearest to issue: redman, reorient, rajput, clothe, rapping, tyndareus, gdr, caldera,
# Nearest to dr: masashi, cremated, mathematica, theon, blackwood, redesign, willamette, opting,
# Nearest to operating: microsoft, bocce, matching, plumbing, ex, dyer, odds, miramax,
# Nearest to prince: rioted, wodehouse, bombs, docetism, reintroduction, rugby, ahmed, diaghilev,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.4798 0.4407 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.5883 0.4610 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.5843 0.4335 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.5542 0.4458 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.6392 0.4863 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.6301 0.4505 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.5939 0.4482 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.5623 0.4347 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.4180 0.4916 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5907 0.5608 sec/batch
# Nearest to was: exploration, sitter, later, respond, leopold, napoleon, alba, another,
# Nearest to its: it, the, personnel, psychohistory, inquire, affricates, incurred, sweeps,
# Nearest to over: seamonkey, tyrannical, prussian, mated, cincinnatus, pozsony, encased, oviedo,
# Nearest to when: next, after, fire, kensington, move, afterwards, remember, dimensional,
# Nearest to have: ever, fujiwara, calumet, has, disabilities, elevated, prone, hoses,
# Nearest to who: possessed, erechtheus, seek, joiner, before, hagia, diplodocus, mobilizing,
# Nearest to were: are, lay, soldiers, rhotic, cooperatives, leaders, reproached, resistance,
# Nearest to known: wilderness, karelian, greatest, diskette, farming, baar, keratin, called,
# Nearest to event: gskola, guns, capitalism, tracker, minicomputers, castaneda, sopranos, whether,
# Nearest to pope: viii, abdicated, conquistadores, grandson, agaves, oireachtas, tabriz, lengthy,
# Nearest to construction: scrutiny, describing, vests, promotions, santiago, harvests, pinguinus, motorway,
# Nearest to scale: depots, naively, succeeding, undesirables, contamination, comstock, domesday, vantaa,
# Nearest to issue: redman, reorient, rajput, clothe, tyndareus, rapping, chairman, theorizing,
# Nearest to dr: masashi, cremated, theon, akc, mathematica, redesign, artwork, opting,
# Nearest to operating: microsoft, bocce, matching, plumbing, dyer, ex, miramax, odds,
# Nearest to prince: rioted, docetism, reintroduction, repudiating, electing, regius, bombs, sobib,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.5504 0.4559 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.5887 0.4468 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.5417 0.4404 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.5955 0.3813 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.5463 0.4184 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4631 0.4698 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.3801 0.4638 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.5492 0.4641 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.5034 0.4926 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4845 0.4723 sec/batch
# Nearest to was: respond, sitter, later, another, exploration, posthumously, suspended, cycles,
# Nearest to its: it, the, inquire, psychohistory, electromotive, incurred, affricates, aml,
# Nearest to over: seamonkey, mated, tyrannical, vedas, cincinnatus, encased, battlezone, prussian,
# Nearest to when: next, dimensional, move, after, remember, kensington, anyone, clotting,
# Nearest to have: has, ever, fujiwara, calumet, had, prone, indicate, disabilities,
# Nearest to who: possessed, erechtheus, hagia, joiner, peltier, brash, mobilizing, seek,
# Nearest to were: are, these, lay, adequate, cooperatives, amply, reproached, rhotic,
# Nearest to known: wilderness, karelian, diskette, proportionate, called, greatest, keratin, grand,
# Nearest to event: gskola, guns, capitalism, castaneda, tracker, minicomputers, whether, dempster,
# Nearest to pope: viii, abdicated, grandson, conquistadores, agaves, oireachtas, tabriz, faithful,
# Nearest to construction: scrutiny, santiago, promotions, vests, motorway, describing, pinguinus, floss,
# Nearest to scale: depots, naively, characteristics, succeeding, contamination, bharata, undesirables, increase,
# Nearest to issue: redman, reorient, rajput, clothe, agong, tyndareus, rapping, luxor,
# Nearest to dr: masashi, cremated, akc, theon, opting, mathematica, reflex, redesign,
# Nearest to operating: microsoft, windows, bocce, gnu, matching, dyer, miramax, ex,
# Nearest to prince: rioted, docetism, bombs, regius, electing, sobib, reintroduction, wodehouse,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.5489 0.4977 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.5247 0.4910 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.5076 0.5191 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.5213 0.4870 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.5336 0.4721 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.5885 0.4827 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.5441 0.1948 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.5167 0.4737 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.4865 0.4797 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.5300 0.4780 sec/batch
# Nearest to was: later, sitter, respond, posthumously, another, alba, vile, exploration,
# Nearest to its: it, the, investments, electromotive, psychohistory, aml, inquire, incurred,
# Nearest to over: seamonkey, metrolink, mated, prussian, infraction, vedas, battlezone, understudy,
# Nearest to when: next, after, move, dimensional, afterwards, kensington, remember, anyone,
# Nearest to have: has, ever, had, fujiwara, disabilities, calumet, prone, heures,
# Nearest to who: possessed, erechtheus, peltier, joiner, seek, hagia, mobilizing, brash,
# Nearest to were: are, these, lay, amply, reproached, rhotic, their, cooperatives,
# Nearest to known: wilderness, karelian, proportionate, residue, called, keratin, greatest, diskette,
# Nearest to event: gskola, guns, castaneda, capitalism, minicomputers, athenaeus, ghetto, dempster,
# Nearest to pope: viii, abdicated, grandson, conquistadores, agaves, oireachtas, faithful, waldseem,
# Nearest to construction: scrutiny, describing, santiago, vests, promotions, motorway, pinguinus, rooftops,
# Nearest to scale: depots, bharata, succeeding, vantaa, undesirables, naively, comstock, conceivable,
# Nearest to issue: redman, reorient, rajput, clothe, agong, tyndareus, gdr, rapping,
# Nearest to dr: masashi, akc, opting, cremated, artwork, theon, mathematica, reflex,
# Nearest to operating: microsoft, windows, bocce, matching, gnu, dyer, miramax, odds,
# Nearest to prince: rioted, docetism, regius, repudiating, sobib, bombs, reintroduction, electing,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.4549 0.4840 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.4958 0.4736 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.4648 0.5125 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.4372 0.3961 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.4671 0.3907 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.4910 0.3871 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.5001 0.3978 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.4920 0.4031 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.4788 0.3890 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.4948 0.3877 sec/batch
# Nearest to was: later, sitter, alba, another, exploration, vile, napoleon, ingress,
# Nearest to its: it, the, psychohistory, investments, electromotive, aml, woodcut, inquire,
# Nearest to over: seamonkey, mated, metrolink, infraction, hongkong, encased, negligible, hob,
# Nearest to when: next, dimensional, after, move, afterwards, kensington, remember, finally,
# Nearest to have: has, had, ever, fujiwara, disabilities, calumet, yolk, prone,
# Nearest to who: possessed, hagia, erechtheus, peltier, mobilizing, brash, seek, darussalam,
# Nearest to were: are, these, habitations, lay, their, soldiers, amply, reproached,
# Nearest to known: wilderness, karelian, called, proportionate, keratin, farming, residue, lutwidge,
# Nearest to event: gskola, guns, castaneda, capitalism, sps, dempster, minicomputers, tracker,
# Nearest to pope: viii, abdicated, conquistadores, agaves, grandson, faithful, waldseem, frideric,
# Nearest to construction: scrutiny, describing, santiago, promotions, vests, motorway, pinguinus, haughton,
# Nearest to scale: depots, vantaa, succeeding, bharata, comstock, naively, deviating, gunships,
# Nearest to issue: redman, reorient, rajput, clothe, agong, tyndareus, rapping, hilde,
# Nearest to dr: masashi, akc, mathematica, opting, reflex, artwork, cremated, theon,
# Nearest to operating: microsoft, bocce, matching, windows, dyer, mos, miramax, odds,
# Nearest to prince: rioted, docetism, regius, sobib, bombs, repudiating, electing, earths,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.4945 0.3936 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.4861 0.3809 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.4675 0.4236 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.3682 0.3667 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.5091 0.3563 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.5328 0.3561 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.4908 0.3538 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.5120 0.3550 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.5045 0.3531 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.4933 0.3541 sec/batch
# Nearest to was: later, sitter, alba, vile, leopold, chooses, posthumously, exploration,
# Nearest to its: it, the, inquire, psychohistory, woodcut, immense, investments, lanthanum,
# Nearest to over: seamonkey, infraction, mated, hongkong, metrolink, hob, encased, negligible,
# Nearest to when: next, afterwards, move, finally, after, fire, dimensional, kensington,
# Nearest to have: has, had, ever, calumet, disabilities, fujiwara, yolk, oligocene,
# Nearest to who: possessed, hagia, erechtheus, peltier, darussalam, mobilizing, grandchildren, blows,
# Nearest to were: are, these, habitations, amply, britons, their, lay, gere,
# Nearest to known: wilderness, keratin, called, proportionate, karelian, lutwidge, bart, residue,
# Nearest to event: gskola, castaneda, guns, sps, capitalism, tracker, dempster, sopranos,
# Nearest to pope: viii, abdicated, agaves, conquistadores, grandson, eugenius, waldseem, faithful,
# Nearest to construction: scrutiny, describing, vests, santiago, motorway, promotions, pinguinus, haughton,
# Nearest to scale: depots, succeeding, vantaa, deviating, gunships, bharata, comstock, naively,
# Nearest to issue: redman, reorient, rajput, clothe, tyndareus, agong, rapping, theorizing,
# Nearest to dr: masashi, akc, artwork, opting, mathematica, theon, cremated, eddings,
# Nearest to operating: microsoft, matching, bocce, windows, miramax, dyer, odds, ex,
# Nearest to prince: rioted, docetism, regius, repudiating, earths, sobib, reintroduction, visibility,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.4952 0.3571 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.4931 0.3540 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.4468 0.3540 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.4512 0.3561 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.3549 0.3548 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.3854 0.3535 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.4952 0.3541 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.4155 0.3531 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.4272 0.3533 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.4337 0.3552 sec/batch
# Nearest to was: later, alba, vile, sitter, posthumously, napoleon, leopold, embarking,
# Nearest to its: it, the, immense, investments, of, inquire, psychohistory, injurious,
# Nearest to over: seamonkey, infraction, hob, cincinnatus, mated, negligible, battlezone, hongkong,
# Nearest to when: dimensional, next, finally, afterwards, after, clotting, move, beachcomber,
# Nearest to have: has, had, ever, disabilities, fujiwara, calumet, oligocene, yolk,
# Nearest to who: possessed, peltier, mobilizing, hagia, erechtheus, grandchildren, darussalam, brash,
# Nearest to were: are, these, habitations, britons, amply, lay, their, adequate,
# Nearest to known: called, wilderness, lutwidge, keratin, karelian, proportionate, as, residue,
# Nearest to event: gskola, castaneda, dempster, tracker, guns, capitalism, sps, wfw,
# Nearest to pope: viii, abdicated, agaves, conquistadores, faithful, eugenius, waldseem, grandson,
# Nearest to construction: describing, scrutiny, vests, santiago, motorway, promotions, haughton, pinguinus,
# Nearest to scale: depots, succeeding, deviating, gunships, vantaa, bharata, naively, comstock,
# Nearest to issue: redman, reorient, rajput, tyndareus, theorizing, agong, rapping, clothe,
# Nearest to dr: masashi, akc, opting, reflex, artwork, mathematica, theon, eddings,
# Nearest to operating: microsoft, matching, bocce, windows, miramax, odds, ex, gpled,
# Nearest to prince: rioted, docetism, repudiating, regius, sobib, earths, bombs, wodehouse,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.4512 0.3555 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.3974 0.3509 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.4722 0.3542 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.4853 0.3539 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.4569 0.3520 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.4532 0.3537 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.4455 0.3529 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.4834 0.3545 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.4838 0.3531 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.4087 0.3512 sec/batch
# Nearest to was: later, vile, sitter, posthumously, alba, is, ingress, another,
# Nearest to its: it, the, immense, investments, inquire, tld, aml, psychohistory,
# Nearest to over: seamonkey, infraction, mated, hongkong, cincinnatus, hob, metrolink, prussian,
# Nearest to when: finally, dimensional, next, after, afterwards, beachcomber, clotting, move,
# Nearest to have: has, had, ever, disabilities, calumet, fujiwara, oligocene, yolk,
# Nearest to who: possessed, hagia, blows, peltier, mobilizing, erechtheus, brash, mania,
# Nearest to were: are, these, habitations, amply, britons, their, adequate, gere,
# Nearest to known: called, wilderness, keratin, lutwidge, residue, proportionate, as, karelian,
# Nearest to event: gskola, castaneda, capitalism, whether, dempster, wfw, tracker, guns,
# Nearest to pope: viii, abdicated, agaves, conquistadores, waldseem, faithful, grandson, eugenius,
# Nearest to construction: describing, vests, scrutiny, motorway, santiago, promotions, haughton, objectification,
# Nearest to scale: depots, gunships, vantaa, bharata, deviating, naively, comstock, succeeding,
# Nearest to issue: redman, reorient, rajput, tyndareus, agong, theorizing, hilde, rapping,
# Nearest to dr: masashi, artwork, reflex, akc, eddings, theon, mathematica, opting,
# Nearest to operating: microsoft, bocce, matching, mos, windows, miramax, ex, odds,
# Nearest to prince: rioted, docetism, sobib, repudiating, regius, earths, wilno, reintroduction,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.4536 0.3570 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.4206 0.3538 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.4712 0.3528 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.4771 0.3541 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.4872 0.3543 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.4794 0.3522 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.4031 0.3544 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.4119 0.3524 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.3986 0.3528 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.4411 0.3529 sec/batch
# Nearest to was: later, is, posthumously, vile, alba, sitter, exploration, chooses,
# Nearest to its: it, the, immense, investments, inquire, tld, aml, of,
# Nearest to over: seamonkey, infraction, hongkong, mated, negligible, hob, triplet, battlezone,
# Nearest to when: afterwards, dimensional, finally, next, clotting, after, move, beachcomber,
# Nearest to have: has, had, ever, disabilities, fujiwara, calumet, yolk, hoses,
# Nearest to who: possessed, blows, hagia, brash, mania, mobilizing, erechtheus, grandchildren,
# Nearest to were: are, these, habitations, amply, their, britons, adequate, cooperatives,
# Nearest to known: called, wilderness, lutwidge, keratin, as, residue, baar, proportionate,
# Nearest to event: gskola, castaneda, whether, tracker, capitalism, wfw, sps, dempster,
# Nearest to pope: viii, abdicated, agaves, conquistadores, waldseem, grandson, eugenius, faithful,
# Nearest to construction: describing, vests, scrutiny, promotions, motorway, santiago, haughton, objectification,
# Nearest to scale: depots, gunships, deviating, vantaa, comstock, bharata, naively, succeeding,
# Nearest to issue: redman, reorient, rajput, theorizing, tyndareus, agong, scientific, clothe,
# Nearest to dr: artwork, masashi, reflex, akc, dick, eddings, theon, mathematica,
# Nearest to operating: microsoft, bocce, matching, mos, windows, gnu, ex, mcs,
# Nearest to prince: rioted, sobib, docetism, regius, earths, repudiating, wodehouse, jef,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.4357 0.3569 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.4464 0.3557 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.4701 0.3549 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.4706 0.3524 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.3823 0.3533 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.4522 0.3523 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.3888 0.3544 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4679 0.3537 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.3487 0.3491 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.4571 0.3549 sec/batch
# Nearest to was: later, is, posthumously, alba, vile, another, golda, napoleon,
# Nearest to its: it, the, investments, immense, woodcut, tld, of, inquire,
# Nearest to over: seamonkey, infraction, hongkong, mated, negligible, hob, triplet, raisin,
# Nearest to when: after, finally, dimensional, afterwards, next, clotting, move, while,
# Nearest to have: had, has, ever, disabilities, injective, since, hoses, calumet,
# Nearest to who: possessed, hagia, mobilizing, blows, slaughters, grandchildren, mania, darussalam,
# Nearest to were: are, these, habitations, their, adequate, britons, several, amply,
# Nearest to known: called, lutwidge, wilderness, as, keratin, proportionate, used, baar,
# Nearest to event: gskola, castaneda, tracker, whether, wfw, dempster, sps, capitalism,
# Nearest to pope: viii, abdicated, agaves, conquistadores, eugenius, grandson, faithful, waldseem,
# Nearest to construction: describing, vests, scrutiny, motorway, promotions, santiago, haughton, objectification,
# Nearest to scale: depots, gunships, deviating, comstock, vantaa, bharata, succeeding, naively,
# Nearest to issue: redman, reorient, rajput, tyndareus, theorizing, agong, oppression, rapping,
# Nearest to dr: artwork, masashi, reflex, eddings, akc, dick, thoracic, opting,
# Nearest to operating: microsoft, matching, bocce, windows, gnu, mos, odds, ex,
# Nearest to prince: rioted, regius, sobib, docetism, repudiating, earths, wodehouse, den,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4799 0.3572 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.4105 0.3512 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.3409 0.3522 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.4558 0.3527 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.4561 0.3544 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.4691 0.3688 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4533 0.3619 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.4946 0.3635 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.4353 0.3657 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3883 0.3644 sec/batch
# Nearest to was: later, is, posthumously, became, odessa, napoleon, golda, never,
# Nearest to its: the, it, of, investments, immense, inquire, electromotive, bylaw,
# Nearest to over: seamonkey, negligible, hongkong, infraction, pozsony, mated, oviedo, suspecting,
# Nearest to when: finally, afterwards, after, dimensional, gibbon, india, clotting, next,
# Nearest to have: has, had, ever, disabilities, since, oligocene, fujiwara, calumet,
# Nearest to who: possessed, darussalam, hagia, slaughters, mobilizing, blows, grandchildren, erechtheus,
# Nearest to were: are, these, habitations, their, britons, several, resistance, amply,
# Nearest to known: called, as, wilderness, lutwidge, baar, used, proportionate, keratin,
# Nearest to event: gskola, whether, castaneda, wfw, tracker, capitalism, sps, reis,
# Nearest to pope: viii, abdicated, agaves, conquistadores, grandson, faithful, eugenius, waldseem,
# Nearest to construction: describing, vests, scrutiny, motorway, santiago, promotions, haughton, objectification,
# Nearest to scale: depots, gunships, deviating, vantaa, comstock, bharata, naively, succeeding,
# Nearest to issue: redman, rajput, reorient, oppression, hilde, tyndareus, gdr, agong,
# Nearest to dr: artwork, masashi, reflex, eddings, akc, dick, obsessed, opting,
# Nearest to operating: microsoft, matching, bocce, gnu, windows, mos, mcs, ex,
# Nearest to prince: rioted, docetism, regius, sobib, repudiating, electing, mourner, reintroduction,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4858 0.3616 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4472 0.3585 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4310 0.3563 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4506 0.3596 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4612 0.3857 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4731 0.3693 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.4569 0.4162 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3448 0.4412 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.3880 0.4273 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.4107 0.4193 sec/batch
# Nearest to was: is, later, became, odessa, ank, posthumously, exploration, leopold,
# Nearest to its: it, the, investments, of, immense, vauxhall, tld, inquire,
# Nearest to over: seamonkey, negligible, infraction, hongkong, raisin, mated, tous, oviedo,
# Nearest to when: after, finally, dimensional, clotting, afterwards, suppressant, india, episcopacy,
# Nearest to have: has, had, ever, disabilities, since, oligocene, having, yolk,
# Nearest to who: possessed, darussalam, seek, mobilizing, erechtheus, mania, hagia, ancestors,
# Nearest to were: are, these, habitations, their, britons, cooperatives, resistance, several,
# Nearest to known: called, as, lutwidge, well, used, wilderness, proportionate, residue,
# Nearest to event: gskola, wfw, castaneda, whether, tracker, sps, capitalism, reis,
# Nearest to pope: viii, abdicated, agaves, conquistadores, eugenius, faithful, waldseem, grandson,
# Nearest to construction: describing, motorway, vests, santiago, scrutiny, promotions, haughton, objectification,
# Nearest to scale: depots, gunships, vantaa, deviating, comstock, succeeding, bharata, naively,
# Nearest to issue: redman, reorient, rajput, hilde, intimidation, agong, oppression, gdr,
# Nearest to dr: artwork, masashi, reflex, eddings, opting, akc, cremated, redesign,
# Nearest to operating: microsoft, matching, bocce, windows, gnu, mos, ex, miramax,
# Nearest to prince: rioted, regius, docetism, sobib, repudiating, mourner, reintroduction, woollen,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4139 0.4220 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4081 0.4169 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3952 0.4170 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.4516 0.4186 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.1654 0.4162 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3710 0.4291 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.3033 0.4255 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4044 0.4435 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4266 0.4719 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.4314 0.4281 sec/batch
# Nearest to was: is, later, posthumously, became, alba, another, embarking, golda,
# Nearest to its: the, it, immense, vauxhall, inquire, tld, investments, of,
# Nearest to over: seamonkey, infraction, negligible, oviedo, mated, battlezone, hongkong, tous,
# Nearest to when: after, while, afterwards, finally, episcopacy, before, next, restyled,
# Nearest to have: had, has, ever, disabilities, never, since, fujiwara, having,
# Nearest to who: possessed, mobilizing, grandchildren, blows, erechtheus, darussalam, seek, hagia,
# Nearest to were: are, these, habitations, their, britons, amply, several, was,
# Nearest to known: called, as, well, lutwidge, wilderness, used, proportionate, baar,
# Nearest to event: gskola, castaneda, wfw, whether, sps, sopranos, tracker, reis,
# Nearest to pope: viii, abdicated, agaves, eugenius, boniface, faithful, conquistadores, waldseem,
# Nearest to construction: describing, vests, motorway, santiago, scrutiny, promotions, haughton, objectification,
# Nearest to scale: depots, gunships, vantaa, deviating, comstock, succeeding, bharata, naively,
# Nearest to issue: redman, reorient, rajput, hilde, agong, brinkley, headingley, oppression,
# Nearest to dr: masashi, artwork, reflex, cremated, eddings, akc, leinster, opting,
# Nearest to operating: microsoft, matching, bocce, windows, gnu, ex, mos, erase,
# Nearest to prince: rioted, regius, docetism, sobib, repudiating, reintroduction, den, wilno,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4719 0.4296 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.5141 0.4204 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.5069 0.4241 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4584 0.4191 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3656 0.4200 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.3635 0.4217 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4367 0.4233 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.4025 0.4219 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.4257 0.4267 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4404 0.4159 sec/batch
# Nearest to was: is, later, became, posthumously, odessa, sitter, vile, were,
# Nearest to its: it, the, vauxhall, immense, aml, inquire, diodes, tld,
# Nearest to over: seamonkey, infraction, negligible, battlezone, mated, hongkong, triplet, hob,
# Nearest to when: after, afterwards, finally, next, dimensional, forfeits, beachcomber, geertz,
# Nearest to have: has, had, ever, since, injective, oligocene, never, having,
# Nearest to who: possessed, darussalam, blows, peltier, mobilizing, erechtheus, ancestors, grandchildren,
# Nearest to were: are, these, habitations, their, amply, britons, was, resistance,
# Nearest to known: called, as, used, well, lutwidge, wilderness, karelian, residue,
# Nearest to event: gskola, castaneda, whether, wfw, sps, capitalism, tracker, reis,
# Nearest to pope: viii, abdicated, agaves, eugenius, conquistadores, faithful, boniface, grandson,
# Nearest to construction: describing, vests, motorway, scrutiny, promotions, santiago, objectification, buildings,
# Nearest to scale: depots, gunships, deviating, vantaa, comstock, succeeding, bharata, naively,
# Nearest to issue: redman, reorient, hilde, rajput, oppression, agong, theorizing, rapping,
# Nearest to dr: artwork, masashi, reflex, akc, eddings, opting, cremated, redesign,
# Nearest to operating: microsoft, matching, bocce, gnu, windows, ex, mos, mcs,
# ...
# Nearest to who: whose, which, whom, that, by, thatcherite, already, where,
# Nearest to were: are, was, being, these, had, is, saw, became,
# Nearest to known: well, referred, as, called, regarded, considered, used, described,
# Nearest to event: events, extinction, catastrophic, sps, whether, pyrenean, reconstituted, beekeepers,
# Nearest to pope: encyclical, faithful, viii, papal, abdicated, eugenius, tabriz, conquistadores,
# Nearest to construction: constructed, building, completed, built, raced, reinforced, planetmath, completion,
# Nearest to scale: large, scales, gunships, tsunami, sacrifices, conceivable, chronometer, subliminal,
# Nearest to issue: issues, crisis, contentious, conflicts, secrets, question, usable, pasture,
# Nearest to dr: ghali, giovani, artwork, tambo, mcgrath, opting, salom, sadd,
# Nearest to operating: systems, kittyhawk, apertures, navigation, odds, operate, organs, relegation,
# Nearest to prince: metadata, princess, woollen, tchaikovsky, kyo, piccadilly, silt, taunus,
# Epoch 10/10 Iteration: 109100 Avg. Training loss: 4.3127 0.4892 sec/batch
# Epoch 10/10 Iteration: 109200 Avg. Training loss: 4.2514 0.5453 sec/batch
# Epoch 10/10 Iteration: 109300 Avg. Training loss: 4.2505 0.5352 sec/batch
# Epoch 10/10 Iteration: 109400 Avg. Training loss: 4.2403 0.5280 sec/batch
# Epoch 10/10 Iteration: 109500 Avg. Training loss: 4.2774 0.5061 sec/batch
# Epoch 10/10 Iteration: 109600 Avg. Training loss: 4.2873 0.4779 sec/batch
# Epoch 10/10 Iteration: 109700 Avg. Training loss: 4.3102 0.4754 sec/batch
# Epoch 10/10 Iteration: 109800 Avg. Training loss: 4.3171 0.4847 sec/batch
# Epoch 10/10 Iteration: 109900 Avg. Training loss: 4.3026 0.4700 sec/batch
# Epoch 10/10 Iteration: 110000 Avg. Training loss: 4.1922 0.4429 sec/batch
# Nearest to was: is, were, became, being, had, are, originally, could,
# Nearest to its: their, the, it, itself, his, of, vauxhall, whose,
# Nearest to over: years, approximately, between, about, several, during, pombal, across,
# Nearest to when: where, before, because, finally, if, after, first, until,
# Nearest to have: has, had, having, since, be, contain, represent, like,
# Nearest to who: whose, which, whom, that, by, thatcherite, rota, where,
# Nearest to were: are, was, being, these, had, saw, represent, is,
# Nearest to known: well, referred, as, regarded, called, considered, described, used,
# Nearest to event: extinction, events, catastrophic, sps, whether, beekeepers, summer, reconstituted,
# Nearest to pope: encyclical, faithful, abdicated, viii, tabriz, papal, eugenius, receiver,
# Nearest to construction: constructed, building, completed, raced, reinforced, built, ongoing, cke,
# Nearest to scale: large, scales, gunships, tsunami, chronometer, conceivable, sidewalks, deltas,
# Nearest to issue: issues, crisis, secrets, contentious, conflicts, question, published, critical,
# Nearest to dr: artwork, ghali, giovani, mcgrath, tambo, opting, salom, dre,
# Nearest to operating: kittyhawk, systems, apertures, navigation, operate, odds, organs, itasca,
# Nearest to prince: metadata, princess, woollen, kyo, tchaikovsky, piccadilly, restraint, silt,
# Epoch 10/10 Iteration: 110100 Avg. Training loss: 4.2987 0.4301 sec/batch
# Epoch 10/10 Iteration: 110200 Avg. Training loss: 4.2094 0.4600 sec/batch
# Epoch 10/10 Iteration: 110300 Avg. Training loss: 4.2914 0.4533 sec/batch
# Epoch 10/10 Iteration: 110400 Avg. Training loss: 4.3015 0.4406 sec/batch
# Epoch 10/10 Iteration: 110500 Avg. Training loss: 4.2533 0.4470 sec/batch
# Epoch 10/10 Iteration: 110600 Avg. Training loss: 4.3029 0.4168 sec/batch
# Epoch 10/10 Iteration: 110700 Avg. Training loss: 4.2325 0.4475 sec/batch
# Epoch 10/10 Iteration: 110800 Avg. Training loss: 4.2573 0.4557 sec/batch
# Epoch 10/10 Iteration: 110900 Avg. Training loss: 4.2320 0.4561 sec/batch
# Epoch 10/10 Iteration: 111000 Avg. Training loss: 4.2505 0.4402 sec/batch
# Nearest to was: is, were, became, being, are, had, originally, could,
# Nearest to its: their, the, it, itself, his, of, vauxhall, unique,
# Nearest to over: years, pombal, between, several, seamonkey, approximately, across, steroid,
# Nearest to when: where, before, because, if, finally, until, after, in,
# Nearest to have: has, had, having, since, be, contain, like, represent,
# Nearest to who: whose, whom, which, that, by, thatcherite, where, rota,
# Nearest to were: are, was, being, these, had, is, saw, became,
# Nearest to known: well, referred, as, regarded, called, considered, described, used,
# Nearest to event: extinction, events, catastrophic, sps, whether, summer, pyrenean, reconstituted,
# Nearest to pope: encyclical, faithful, viii, abdicated, tabriz, papal, eugenius, receiver,
# Nearest to construction: constructed, building, completed, raced, built, cke, ongoing, scrutiny,
# Nearest to scale: scales, large, gunships, tsunami, chronometer, conceivable, kinsey, sacrifices,
# Nearest to issue: issues, crisis, conflicts, secrets, contentious, question, usable, critical,
# Nearest to dr: artwork, ghali, giovani, mcgrath, opting, tambo, salom, sadd,
# Nearest to operating: kittyhawk, systems, apertures, navigation, operate, itasca, odds, forests,
# Nearest to prince: princess, metadata, woollen, kyo, tchaikovsky, restraint, bai, silt,
# Epoch 10/10 Iteration: 111100 Avg. Training loss: 4.3242 0.4221 sec/batch
# Epoch 10/10 Iteration: 111200 Avg. Training loss: 4.1842 0.4051 sec/batch
# Epoch 10/10 Iteration: 111300 Avg. Training loss: 4.2974 0.4155 sec/batch
# Epoch 10/10 Iteration: 111400 Avg. Training loss: 4.2771 0.4696 sec/batch
# Epoch 10/10 Iteration: 111500 Avg. Training loss: 4.2612 0.5026 sec/batch
# Epoch 10/10 Iteration: 111600 Avg. Training loss: 4.1493 0.4775 sec/batch
# Epoch 10/10 Iteration: 111700 Avg. Training loss: 4.3034 0.4473 sec/batch
# Epoch 10/10 Iteration: 111800 Avg. Training loss: 4.3044 0.3853 sec/batch
# Epoch 10/10 Iteration: 111900 Avg. Training loss: 4.2727 0.3908 sec/batch
# Epoch 10/10 Iteration: 112000 Avg. Training loss: 4.3070 0.5027 sec/batch
# Nearest to was: is, were, became, being, are, had, originally, could,
# Nearest to its: their, the, his, itself, it, of, unique, distinctive,
# Nearest to over: years, approximately, several, between, pombal, ordinates, seamonkey, germ,
# Nearest to when: where, before, because, if, finally, that, until, after,
# Nearest to have: has, had, having, since, be, contain, like, appear,
# Nearest to who: whom, whose, which, that, by, thatcherite, where, rota,
# Nearest to were: are, was, being, these, had, is, saw, remained,
# Nearest to known: well, referred, as, regarded, called, considered, described, used,
# Nearest to event: events, extinction, catastrophic, whether, sps, outcome, summer, beekeepers,
# Nearest to pope: encyclical, faithful, viii, tabriz, abdicated, eugenius, papal, agaves,
# Nearest to construction: constructed, building, completed, built, raced, reinforced, cke, finalized,
# Nearest to scale: large, scales, tsunami, gunships, conceivable, deltas, hanoverians, chronometer,
# Nearest to issue: issues, crisis, secrets, contentious, question, conflicts, usable, saccharine,
# Nearest to dr: artwork, ghali, giovani, tambo, mcgrath, opting, salom, sadd,
# Nearest to operating: systems, kittyhawk, apertures, navigation, odds, system, itasca, operate,
# Nearest to prince: princess, metadata, woollen, kyo, tchaikovsky, isospin, silt, bai,
# Epoch 10/10 Iteration: 112100 Avg. Training loss: 4.3332 0.5462 sec/batch
# Epoch 10/10 Iteration: 112200 Avg. Training loss: 4.2304 0.5078 sec/batch
# Epoch 10/10 Iteration: 112300 Avg. Training loss: 4.2641 0.4976 sec/batch
# Epoch 10/10 Iteration: 112400 Avg. Training loss: 4.3162 0.5296 sec/batch
# Epoch 10/10 Iteration: 112500 Avg. Training loss: 4.2969 0.4318 sec/batch
# Epoch 10/10 Iteration: 112600 Avg. Training loss: 4.2460 0.4893 sec/batch
# Epoch 10/10 Iteration: 112700 Avg. Training loss: 4.3097 0.5267 sec/batch
# Epoch 10/10 Iteration: 112800 Avg. Training loss: 4.2788 0.3860 sec/batch
# Epoch 10/10 Iteration: 112900 Avg. Training loss: 4.3248 0.3821 sec/batch
# Epoch 10/10 Iteration: 113000 Avg. Training loss: 4.2851 0.4650 sec/batch
# Nearest to was: is, were, became, being, are, had, originally, could,
# Nearest to its: their, the, his, itself, it, of, vauxhall, distinctive,
# Nearest to over: between, approximately, years, several, ordinates, under, germ, pombal,
# Nearest to when: where, because, before, if, finally, until, once, after,
# Nearest to have: has, had, having, since, be, contain, represent, appear,
# Nearest to who: whom, whose, which, that, by, where, thatcherite, while,
# Nearest to were: are, was, being, these, is, had, remained, themselves,
# Nearest to known: well, referred, as, regarded, called, considered, described, used,
# Nearest to event: extinction, events, catastrophic, whether, sps, beekeepers, pyrenean, reconstituted,
# Nearest to pope: encyclical, faithful, viii, papal, abdicated, tabriz, eugenius, thereabouts,
# Nearest to construction: constructed, completed, built, building, cke, raced, reinforced, creation,
# Nearest to scale: scales, large, tsunami, gunships, deltas, conceivable, hanoverians, chronometer,
# Nearest to issue: issues, crisis, contentious, secrets, question, conflicts, pasture, usable,
# Nearest to dr: ghali, artwork, giovani, tambo, mcgrath, opting, sadd, reflex,
# Nearest to operating: kittyhawk, systems, apertures, navigation, odds, cheyenne, forests, itasca,
# Nearest to prince: princess, metadata, woollen, kyo, tchaikovsky, isospin, stringer, restraint,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 4.1663 0.5148 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.2488 0.4602 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.2589 0.3824 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.2832 0.3823 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.2479 0.3835 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.2939 0.3861 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.2006 0.3846 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 3.9753 0.3864 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 4.1605 0.3878 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.2323 0.3860 sec/batch
# Nearest to was: is, were, became, being, are, had, could, originally,
# Nearest to its: their, the, his, of, it, itself, vauxhall, splendor,
# Nearest to over: approximately, between, years, ordinates, across, during, several, under,
# Nearest to when: before, where, because, if, until, finally, in, after,
# Nearest to have: has, had, having, since, be, contain, recently, never,
# Nearest to who: whom, which, whose, that, by, where, thatcherite, while,
# Nearest to were: are, was, being, these, is, had, remained, became,
# Nearest to known: well, as, referred, regarded, called, described, considered, such,
# Nearest to event: extinction, events, catastrophic, sps, whether, reconstituted, beekeepers, funeral,
# Nearest to pope: encyclical, faithful, viii, eugenius, tabriz, abdicated, papal, thereabouts,
# Nearest to construction: constructed, completed, built, building, raced, reinforced, creation, cke,
# Nearest to scale: large, scales, tsunami, gunships, hanoverians, conceivable, deltas, kinsey,
# Nearest to issue: issues, crisis, contentious, secrets, conflicts, question, pasture, saccharine,
# Nearest to dr: ghali, giovani, tambo, artwork, mcgrath, opting, ilyich, sadd,
# Nearest to operating: kittyhawk, systems, apertures, navigation, forests, odds, operate, organs,
# Nearest to prince: princess, metadata, kyo, woollen, tchaikovsky, stringer, owen, isospin,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.2722 0.3889 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.2977 0.3863 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.2945 0.3858 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.3490 0.3864 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.3559 0.3890 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.3467 0.3874 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 4.2809 0.3859 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 4.1170 0.3918 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 4.3213 0.3862 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.2786 0.3850 sec/batch
# Nearest to was: is, were, became, being, are, had, could, remained,
# Nearest to its: their, the, of, it, his, itself, distinctive, whose,
# Nearest to over: approximately, years, between, ordinates, under, several, across, about,
# Nearest to when: where, before, because, if, until, finally, then, in,
# Nearest to have: has, had, having, since, be, contain, recently, require,
# Nearest to who: whom, whose, which, that, where, by, thatcherite, bleek,
# Nearest to were: are, was, being, these, is, had, remained, themselves,
# Nearest to known: well, referred, as, regarded, called, described, considered, used,
# Nearest to event: extinction, events, catastrophic, whether, sps, reconstituted, beekeepers, tatra,
# Nearest to pope: encyclical, faithful, viii, eugenius, abdicated, papal, tabriz, receiver,
# Nearest to construction: constructed, completed, built, building, raced, cke, scrutiny, reinforced,
# Nearest to scale: large, scales, gunships, tsunami, conceivable, chronometer, deltas, hanoverians,
# Nearest to issue: issues, crisis, secrets, contentious, question, conflicts, usable, pasture,
# Nearest to dr: giovani, ghali, artwork, tambo, opting, mcgrath, eddings, muir,
# Nearest to operating: systems, kittyhawk, apertures, navigation, organs, itasca, operate, system,
# Nearest to prince: princess, metadata, woollen, kyo, bai, isospin, abduct, tchaikovsky,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.2673 0.3884 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.2455 0.3851 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 4.3488 0.3928 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.2529 0.3848 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.2491 0.3820 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 4.0025 0.3811 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.2713 0.3833 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.2681 0.3836 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.1756 0.3825 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.2764 0.3821 sec/batch
# Nearest to was: is, were, became, being, are, had, could, originally,
# Nearest to its: their, the, his, itself, it, of, unique, distinctive,
# Nearest to over: years, under, approximately, between, several, ordinates, isbn, pombal,
# Nearest to when: where, before, because, if, finally, after, until, then,
# Nearest to have: has, had, having, since, be, contain, recently, oda,
# Nearest to who: whom, which, that, whose, by, where, thatcherite, already,
# Nearest to were: are, was, being, these, had, is, remained, saw,
# Nearest to known: well, referred, as, regarded, called, described, considered, used,
# Nearest to event: extinction, events, catastrophic, sps, beekeepers, whether, reconstituted, tatra,
# Nearest to pope: encyclical, faithful, eugenius, viii, abdicated, papal, tabriz, thereabouts,
# Nearest to construction: constructed, completed, building, built, raced, cke, textiles, clothing,
# Nearest to scale: large, scales, gunships, tsunami, sidewalks, deltas, quantities, moody,
# Nearest to issue: issues, crisis, question, contentious, secrets, conflicts, controversy, usable,
# Nearest to dr: giovani, artwork, ghali, tambo, mcgrath, reflex, ilyich, opting,
# Nearest to operating: systems, kittyhawk, apertures, navigation, system, gnu, itasca, organs,
# Nearest to prince: princess, metadata, tchaikovsky, woollen, isospin, stringer, hd, kyo,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.2751 0.3755 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.2689 0.3568 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.2286 0.3562 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.2953 0.3575 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.3072 0.3580 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
